# %%
a = 1 # int(정수형)
b = 0.1 # float(소수형)
c = '영진 짱짱맨' # str(문자형) 참고 : ""
d = '성커 짱짱맨'
e = True # 진실
f = False # 거짓

# %%
a
# Out:
# 1

# %%
b
# Out:
# 0.1

# %%
c
# Out:
# '영진 짱짱맨'

# %%
d = '성커 짱짱맨'

# %%
d
# Out:
# '성커 짱짱맨'

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 0.1
# 영진 짱짱맨
# 성커 짱짱맨

# %%
print(type(a),type(b),type(c),type(d))
dir(c)
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'str'>
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
# ...
